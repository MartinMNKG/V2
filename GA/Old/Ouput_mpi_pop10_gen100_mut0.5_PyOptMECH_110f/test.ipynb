# %%
import numpy as np 
import pandas as pd 
import pickle
import matplotlib.pyplot as plt

# %%
obj = pd.read_pickle(f'F_ref.pkl')
data =pd.read_csv("Ouput_mpi_pop10_gen100_mut0.5.csv")

# %%
F_ref = obj[0]
print(data["min"])
plt.title("Fitness/Fitness_ref PyoptMech ")
plt.plot(data["min"]/F_ref)
plt.yscale("log")
# Out:
# 0      4416.895134
# 1       543.992994
# 2       543.992994
# 3       543.992994
# 4       543.992994
#           ...
# 96      275.995862
# 97      275.995862
# 98      275.995862
# 99      275.995862
# 100     275.995862
# Name: min, Length: 101, dtype: float64
