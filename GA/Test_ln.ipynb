# %%
import pandas as pd
import pickle
import matplotlib.pyplot as plt

# %%
data_noInd_1 = pd.read_csv("/work/kotlarcm/WORK/V2/GA/Start_mpi_pop10_gen100_PyOptMECH_Case10_wo_IndRedu_test1/Loogbox_Optim_Pop10_Gen100_PyOptMECH_Case_10.csv")
ref_noInd_1 = pd.read_pickle("/work/kotlarcm/WORK/V2/GA/Start_mpi_pop10_gen100_PyOptMECH_Case10_wo_IndRedu_test1/F_ref.pkl")

data_noInd_2 = pd.read_csv("/work/kotlarcm/WORK/V2/GA/Start_mpi_pop10_gen100_PyOptMECH_Case10_wo_IndRedu_test2/Loogbox_Optim_Pop10_Gen100_PyOptMECH_Case_10.csv")
ref_noInd_2 = pd.read_pickle("/work/kotlarcm/WORK/V2/GA/Start_mpi_pop10_gen100_PyOptMECH_Case10_wo_IndRedu_test2/F_ref.pkl")


Data_yeInd_1 = pd.read_csv("/work/kotlarcm/WORK/V2/GA/Start_mpi_pop10_gen100_PyOptMECH_Case10_wi_IndRedu_test1/Loogbox_Optim_Pop10_Gen100_PyOptMECH_Case_10.csv")
ref_yeInd_1 = pd.read_pickle("/work/kotlarcm/WORK/V2/GA/Start_mpi_pop10_gen100_PyOptMECH_Case10_wi_IndRedu_test1/F_ref.pkl")

Data_yeInd_2 = pd.read_csv("/work/kotlarcm/WORK/V2/GA/Start_mpi_pop10_gen100_PyOptMECH_Case10_wi_IndRedu_test2/Loogbox_Optim_Pop10_Gen100_PyOptMECH_Case_10.csv")
ref_yeInd_2 = pd.read_pickle("/work/kotlarcm/WORK/V2/GA/Start_mpi_pop10_gen100_PyOptMECH_Case10_wi_IndRedu_test2/F_ref.pkl")

# %%
plt.plot(data_noInd_1["gen"],data_noInd_1['min']/ref_noInd_1[0],label="Without Reduced as Individual test 1")
plt.plot(data_noInd_2["gen"],data_noInd_2['min']/ref_noInd_2[0],label="Without Reduced as Individual test2")
plt.plot(Data_yeInd_1["gen"],Data_yeInd_1['min']/ref_yeInd_1[0],label="With Reduced as Individual test 1")
plt.plot(Data_yeInd_2["gen"],Data_yeInd_2['min']/ref_yeInd_2[0],label="With Reduced as Individual test 2")
plt.legend()
plt.xlabel("gen")
plt.ylabel("Fitness/FitnessRef")
plt.title("Fitness : PyOptMech")
plt.yscale("log")

# %%
data = pd.read_csv("/work/kotlarcm/WORK/V2/GA/Start_mpi_pop50_gen200_PyOptMECH_Case4_wiInd/Loogbox_Optim_Pop50_Gen200_PyOptMECH_Case_4.csv")
ref_data = pd.read_pickle("/work/kotlarcm/WORK/V2/GA/Start_mpi_pop50_gen200_PyOptMECH_Case4_wiInd/F_ref.pkl")

data2 = pd.read_csv("/work/kotlarcm/WORK/V2/GA/Start_mpi_pop50_gen200_PyOptMECH_Case4_woInd/Loogbox_Optim_Pop50_Gen200_PyOptMECH_Case_4.csv")
ref_data2 = pd.read_pickle("/work/kotlarcm/WORK/V2/GA/Start_mpi_pop50_gen200_PyOptMECH_Case4_woInd/F_ref.pkl")

data_3 = pd.read_csv("/work/kotlarcm/WORK/V2/GA/Start_mpi_pop50_gen200_PyOptMECH_Case4_wiInd_t2/Loogbox_Optim_Pop50_Gen200_PyOptMECH_Case_4.csv")
ref_data_3 = pd.read_pickle("/work/kotlarcm/WORK/V2/GA/Start_mpi_pop50_gen200_PyOptMECH_Case4_wiInd_t2/F_ref.pkl")

data_4 = pd.read_csv("/work/kotlarcm/WORK/V2/GA/Start_mpi_pop50_gen200_PyOptMECH_Case4_woInd_t2/Loogbox_Optim_Pop50_Gen200_PyOptMECH_Case_4.csv")
ref_data_4 = pd.read_pickle("/work/kotlarcm/WORK/V2/GA/Start_mpi_pop50_gen200_PyOptMECH_Case4_woInd_t2/F_ref.pkl")

# %%
plt.plot(data["gen"],data['min']/ref_data[0],label="With Reduced as Individual test 1")
plt.plot(data_3["gen"],data_3['min']/ref_data_3[0],label="With Reduced as Individual test 2")
plt.plot(data2["gen"],data2['min']/ref_data2[0],label="Without Reduced as Individual test 1")
plt.plot(data_4["gen"],data_4['min']/ref_data_4[0],label="Without Reduced as Individual test 2")
plt.legend()
plt.xlabel("gen")
plt.ylabel("Fitness/FitnessRef")
plt.title("Fitness : PyOptMech")
plt.yscale("log")
