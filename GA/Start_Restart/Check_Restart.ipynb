# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data_start = pd.read_csv("/work/kotlarcm/WORK/V2/GA/Start_mpi_pop10_gen100_PyOptMECH_Case10/hist/Output_mpi_gen17.csv")
data_restart = pd.read_csv("/work/kotlarcm/WORK/V2/GA/Restart_mpi_pop10_gen100_PyOptMECH_Case10/Loogbox_Optim_Pop10_Gen100_PyOptMECH_Case_10.csv")

# %%
plt.plot(data_start["gen"]+data_restart["gen"],data_start["min"]+data_restart["min"])
